# %%
import pickle

# %%
with open('all_data.pickle', 'rb') as f:
    load_data = pickle.load(f)

# %%
load_data
# Out:
#         CO    DO      Humid  LPG      MQ137 SMOKE  Temperature   data_type  \
# 71     NaN  10.4        NaN  NaN        NaN   NaN          NaN          DO
# 74     NaN   NaN        NaN  NaN        NaN   NaN    12.845000  water_temp
# 76     NaN  9.46        NaN  NaN        NaN   NaN          NaN          DO
# 114    NaN  10.5        NaN  NaN        NaN   NaN          NaN          DO
# 151    NaN  10.2        NaN  NaN        NaN   NaN          NaN          DO
# 217    NaN  9.36        NaN  NaN        NaN   NaN    13.570000          DO
# 221    NaN  9.62        NaN  NaN        NaN   NaN          NaN          DO
# 266    NaN   NaN        NaN  NaN        NaN   NaN    12.845000  water_temp
# 277    NaN  10.6        NaN  NaN        NaN   NaN          NaN          DO
# 295    NaN  9.55        NaN  NaN        NaN   NaN          NaN          DO
# 327    NaN   NaN        NaN  NaN        NaN   NaN    13.320000  water_temp
# ...

# %%
print(load_data)
# Out:
#         CO    DO      Humid  LPG      MQ137 SMOKE  Temperature   data_type  \
# 71     NaN  10.4        NaN  NaN        NaN   NaN          NaN          DO
# 74     NaN   NaN        NaN  NaN        NaN   NaN    12.845000  water_temp
# 76     NaN  9.46        NaN  NaN        NaN   NaN          NaN          DO
# 114    NaN  10.5        NaN  NaN        NaN   NaN          NaN          DO
# 151    NaN  10.2        NaN  NaN        NaN   NaN          NaN          DO
# 217    NaN  9.36        NaN  NaN        NaN   NaN    13.570000          DO
# 221    NaN  9.62        NaN  NaN        NaN   NaN          NaN          DO
# 266    NaN   NaN        NaN  NaN        NaN   NaN    12.845000  water_temp
# 277    NaN  10.6        NaN  NaN        NaN   NaN          NaN          DO
# 295    NaN  9.55        NaN  NaN        NaN   NaN          NaN          DO
# 327    NaN   NaN        NaN  NaN        NaN   NaN    13.320000  water_temp
# ...
